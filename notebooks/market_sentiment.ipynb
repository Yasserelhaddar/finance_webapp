# %%
import finnhub
finnhub_client = finnhub.Client(api_key="")

print(finnhub_client.company_news('AAPL', _from="2024-01-01", to="2024-03-10"))
# Out:
# [{'category': 'company', 'datetime': 1710082439, 'headline': 'Apple MacBook Air 2024 review: The best keeps getting better', 'id': 126428777, 'image': 'https://s.yimg.com/ny/api/res/1.2/m3WqFBBn4Oa3.jZy0Nb7vQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2024-03/cf45a5d0-dd7e-11ee-9ff6-5a1e53e2f4b4', 'related': 'AAPL', 'source': 'Yahoo', 'summary': "Apple's M3-powered MacBook Air 13-inch and 15-inch promise strong performance and exceptional battery life.", 'url': 'https://finnhub.io/api/news?id=0441c92519a6eb1f4212dcbf4d6e0d1f4ac146f1c43a40237e5a795f0ccaa30f'}, {'category': 'company', 'datetime': 1710074100, 'headline': 'Apple Could Launch Its Most Important Product Since the iPhone This Summer, According to a Pair of Wall Street Analysts', 'id': 126425378, 'image': 'https://g.foolcdn.com/editorial/images/768445/getty-images-apple-store.jpeg', 'related': 'AAPL', 'source': 'Yahoo', 'summary': 'It could be a much-needed growth catalyst for the
# ...
